# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_row', 111)
pd.set_option('display.max_column', 111)

# %%
#Importation de la base de données
data = pd.read_csv('data/DS_project3.csv', sep='\t', nrows= 20000)
# Out:
# C:\tools\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0,13,27,28,29,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head(5)
# Out:
#                  code                                                url  \
# 0   00000000000000225  http://world-en.openfoodfacts.org/product/0000...
# 1       0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 2       0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 3  000000000003327986  http://world-en.openfoodfacts.org/product/0000...
# 4  000000000004622327  http://world-en.openfoodfacts.org/product/0000...
#
#           creator   created_t      created_datetime  last_modified_t  \
# 0  nutrinet-sante  1623855208  2021-06-16T14:53:28Z       1623855209
# 1         kiliweb  1529059080  2018-06-15T10:38:00Z       1561463718
# 2        isagoofy  1539464774  2018-10-13T21:06:14Z       1539464817
# 3         kiliweb  1574175736  2019-11-19T15:02:16Z       1574175737
# 4         kiliweb  1619501895  2021-04-27T05:38:15Z       1619501897
#
#   last_modified_datetime                  product_name  \
# ...

# %% [raw]
# I. Exploratory Data Analysis
# Objectif de cette partie: Comprendre au maximum les données dont on dispose pour définir une stratégie de modélisation.
#     A. Analyse de la forme:
#         1. Identification de la target
#         2. Nombre de lignes et de colonnes
#         3. Identification des valeurs manquantes
#         4. Types de variables.
#     B. Analyse de fond:
#         1. Visualisation de la target (histogramme--continue/ bloxplot--discrète)
#         2. Compréhension des différentes variables (recherche)
#         3. Visualisation des relations: features/ target
#         4. Identification des outliers
# II. Prepocessing
# Objectif de cette partie: Transformer la data pour la mettre dans un format propice au Machine Learning
#     A. Création du Train Set/Test Set
#     B. Elimination des NaN: dropna(), imputation, colonnes "vides"
#     C. Encodage
#     D. Suppression des outliers néfastes au modèle
#     E. Feature sélection
#     F. Feature engineering
#     G. Feature Sealing
# III. Modeling
# Object de cette partie: Développer un modèle de Machine Learning capable de répondre à l'objectif final.
#     A. Définir une fonction d'évaluation
#     B. Entraînement des différents modèles
#     C. Optimisation avec GridSearchCV
#     D. Analyse des erreurs et retour au prepocessing/ EDA
#     E. Learning curve et prise de décision

# %%
df = data.copy()

# %%
df.shape
# Out:
# (20000, 186)

# %%
df.dtypes.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending=True)
# Out:
# code                          0.0
# url                           0.0
# creator                       0.0
# created_t                     0.0
# created_datetime              0.0
#                              ...
# -linoleic-acid_100g           1.0
# omega-6-fat_100g              1.0
# -docosahexaenoic-acid_100g    1.0
# -gondoic-acid_100g            1.0
# carnitine_100g                1.0
# Length: 186, dtype: float64

# %%
df = df[df.columns[df.isna().sum()/df.shape[0] <0.9]]
df.head()
# Out:
#                  code                                                url  \
# 0   00000000000000225  http://world-en.openfoodfacts.org/product/0000...
# 1       0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 2       0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 3  000000000003327986  http://world-en.openfoodfacts.org/product/0000...
# 4  000000000004622327  http://world-en.openfoodfacts.org/product/0000...
#
#           creator   created_t      created_datetime  last_modified_t  \
# 0  nutrinet-sante  1623855208  2021-06-16T14:53:28Z       1623855209
# 1         kiliweb  1529059080  2018-06-15T10:38:00Z       1561463718
# 2        isagoofy  1539464774  2018-10-13T21:06:14Z       1539464817
# 3         kiliweb  1574175736  2019-11-19T15:02:16Z       1574175737
# 4         kiliweb  1619501895  2021-04-27T05:38:15Z       1619501897
#
#   last_modified_datetime                  product_name   brands brands_tags  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#                  code                                                url  \
# 0   00000000000000225  http://world-en.openfoodfacts.org/product/0000...
# 1       0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 2       0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 3  000000000003327986  http://world-en.openfoodfacts.org/product/0000...
# 4  000000000004622327  http://world-en.openfoodfacts.org/product/0000...
#
#           creator   created_t      created_datetime  last_modified_t  \
# 0  nutrinet-sante  1623855208  2021-06-16T14:53:28Z       1623855209
# 1         kiliweb  1529059080  2018-06-15T10:38:00Z       1561463718
# 2        isagoofy  1539464774  2018-10-13T21:06:14Z       1539464817
# 3         kiliweb  1574175736  2019-11-19T15:02:16Z       1574175737
# 4         kiliweb  1619501895  2021-04-27T05:38:15Z       1619501897
#
#   last_modified_datetime                  product_name   brands brands_tags  \
# ...

# %%
df['product_name'].value_counts(normalize=True)
# Out:
# Ice cream                                           0.002210
# Ice Cream                                           0.001696
# Soda                                                0.001439
# Hard candy                                          0.001131
# 100% juice                                          0.000925
#                                                       ...
# 28% Vegetable Oil Spread                            0.000051
# Kroger, homestyle pasta sauce, parmesan & romano    0.000051
# Gumbo sauce                                         0.000051
# Solène céréales poulet                              0.000051
# Real bacon bits                                     0.000051
# Name: product_name, Length: 16309, dtype: float64
